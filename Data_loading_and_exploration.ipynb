# %%
import pandas as pd

# %%
datafr= pd.read_csv('/content/nft_sales.csv')

# %%
datafr
# Out:
#                Collections           Sales     Buyers        Txns     Owners
# 0            Axie Infinity  $4,090,222,023  1,790,587  17,670,824  2,130,467
# 1     Bored Ape Yacht Club  $2,439,754,017     12,052      32,670      6,586
# 2              CryptoPunks  $2,388,467,992      6,076      22,269      3,804
# 3    Mutant Ape Yacht Club  $1,744,822,678     23,768      51,775     13,121
# 4               Art Blocks  $1,310,734,558     33,549     184,470     36,091
# ..                     ...             ...        ...         ...        ...
# 245             Mindblowon     $21,255,015     11,313      16,333      3,973
# 246        Sipherian Surge     $21,053,426      6,210      15,023      3,636
# 247            Gutter Rats     $20,915,001      2,931       5,209        NaN
# 248             Wool Pouch     $20,911,179      2,249       6,139      3,270
# 249            Los Muertos     $20,901,871     11,143      25,406      4,328
#
# [250 rows x 5 columns]

# %%
rows, columns = datafr.shape
print('columns = ', columns)
print('rows = ', rows)
# Out:
# columns =  5
# rows =  250

# %%
datafr.count()
# Out:
# Collections    250
# Sales          250
# Buyers         250
# Txns           250
# Owners         231
# dtype: int64

# %%
datafr.head(4)
# Out:
#              Collections           Sales     Buyers        Txns     Owners
# 0          Axie Infinity  $4,090,222,023  1,790,587  17,670,824  2,130,467
# 1   Bored Ape Yacht Club  $2,439,754,017     12,052      32,670      6,586
# 2            CryptoPunks  $2,388,467,992      6,076      22,269      3,804
# 3  Mutant Ape Yacht Club  $1,744,822,678     23,768      51,775     13,121

# %%
datafr.tail(4)
# Out:
#          Collections        Sales  Buyers    Txns Owners
# 246  Sipherian Surge  $21,053,426   6,210  15,023  3,636
# 247      Gutter Rats  $20,915,001   2,931   5,209    NaN
# 248       Wool Pouch  $20,911,179   2,249   6,139  3,270
# 249      Los Muertos  $20,901,871  11,143  25,406  4,328

# %%
datafr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Collections  250 non-null    object
#  1   Sales        250 non-null    object
#  2   Buyers       250 non-null    object
#  3   Txns         250 non-null    object
#  4   Owners       231 non-null    object
# dtypes: object(5)
# memory usage: 9.9+ KB

# %%
datafr.describe()
# Out:
#           Collections           Sales     Buyers    Txns Owners
# count             250             250        250     250    231
# unique            250             250        250     249    227
# top     Axie Infinity  $4,090,222,023  1,790,587  10,653  4,373
# freq                1               1          1       2      2

# %%
datafr['Owners']= pd.to_numeric(datafr['Owners'], errors='coerce')
datafr['Owners'].mean()
# Out:
# 355.5

# %%
datafr.describe()
# Out:
#            Owners
# count    6.000000
# mean   355.500000
# std    292.618352
# min    114.000000
# 25%    145.000000
# 50%    219.000000
# 75%    551.750000
# max    798.000000

# %%
datafr["Sales"][2:6]
# Out:
# 2    $2,388,467,992
# 3    $1,744,822,678
# 4    $1,310,734,558
# 5    $1,054,265,540
# Name: Sales, dtype: object

# %%
datafr[15:34]
# Out:
#                  Collections         Sales  Buyers       Txns  Owners
# 15     Bored Ape Kennel Club  $350,304,508  10,576     24,508     NaN
# 16                      Loot  $280,380,848   4,310     12,115     NaN
# 17            World Of Women  $248,761,610  10,959     27,412     NaN
# 18                 Cryptoadz  $246,020,311  10,116     22,704     NaN
# 19                VeeFriends  $240,107,018   6,545     14,833     NaN
# 20                   Crabada  $226,918,588  10,179    203,615     NaN
# 21            Parallel Alpha  $225,864,657  26,274    142,821     NaN
# 22                     Beanz  $225,745,147  10,902     23,670     NaN
# 23                CyberKongz  $203,993,499   4,227      7,310     NaN
# 24  Bored Ape Chemistry Club  $200,511,690   2,220      3,882     NaN
# 25             Farmers World  $196,437,030  78,198  5,400,552     NaN
# 26                   ZED RUN  $192,086,783  79,686    678,567     NaN
# ...

# %%
datafr.isnull().sum()
# Out:
# Collections      0
# Sales            0
# Buyers           0
# Txns             0
# Owners         244
# dtype: int64

# %%
datafr.max()
# Out:
# Collections    the littles NFT
# Sales              $99,537,264
# Buyers                   9,977
# Txns                    96,408
# Owners                   798.0
# dtype: object

# %%
datafr.columns
# Out:
# Index(['Collections', 'Sales', 'Buyers', 'Txns', 'Owners'], dtype='object')

# %%
datafr[datafr['Sales']==datafr['Sales'].max()]
# Out:
#                Collections        Sales     Buyers        Txns  Owners
# 0            Axie Infinity  $99,537,264  1,790,587  17,670,824     NaN
# 1     Bored Ape Yacht Club  $99,537,264     12,052      32,670     NaN
# 2              CryptoPunks  $99,537,264      6,076      22,269     NaN
# 3    Mutant Ape Yacht Club  $99,537,264     23,768      51,775     NaN
# 4               Art Blocks  $99,537,264     33,549     184,470     NaN
# ..                     ...          ...        ...         ...     ...
# 245             Mindblowon  $99,537,264     11,313      16,333     NaN
# 246        Sipherian Surge  $99,537,264      6,210      15,023     NaN
# 247            Gutter Rats  $99,537,264      2,931       5,209     NaN
# 248             Wool Pouch  $99,537,264      2,249       6,139     NaN
# 249            Los Muertos  $99,537,264     11,143      25,406     NaN
#
# [250 rows x 5 columns]
